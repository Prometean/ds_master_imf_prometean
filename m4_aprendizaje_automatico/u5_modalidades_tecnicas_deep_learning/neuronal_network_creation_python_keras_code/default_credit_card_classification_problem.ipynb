# %% [markdown]
# # Carga de librerías:

# %%
import pandas as pd
pd.options.display.max_columns = 500
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Definición de funciones:

# %%
def relaciones_vs_target(X, Y, return_type='axes'):
    '''
    Función que representa gráficos de dispersión de las variables
    en X en función a la variable Y
    '''
    fig_tot = (len(X.columns))
    fig_por_fila = 4.
    tamanio_fig = 4.
    num_filas = int( np.ceil(fig_tot/fig_por_fila) )    
    plt.figure( figsize=( fig_por_fila*tamanio_fig+5, num_filas*tamanio_fig+5 ) )
    c = 0 
    for i, col in enumerate(X.columns):
        plt.subplot(num_filas, int(fig_por_fila), i+1)
        sns.scatterplot(x=X[col], y=Y)
        plt.title( '%s vs %s' % (col, 'target') )
        plt.ylabel('Target')
        plt.xlabel(col)
    plt.show()

def represento_doble_hist(x_1, x_0, n_bins=11, title='', label_1='Clase 1', 
                          label_0='Clase 0', density=0):
    '''
    Función que recibe dos distribuciones de probabilidad y las representa
    en el mismo gráfico
    '''
    bins = n_bins
    plt.hist(x_1, bins, density = density, alpha=0.5, label=label_1, color='red')    
    plt.hist(x_0, bins, density = density, alpha=0.5, label=label_0, color='green')
    plt.title(title)
    plt.legend(loc='best') 

def hist_pos_neg_feat(x, y, density=0, nbins=11, targets=(0,1)):
    '''
    Representa las variables en x divididas en dos distribuciones
    según su valor de y sea 1 o 0
    '''
    fig_tot = len(x.columns)
    fig_tot_fila = 4.; fig_tamanio = 4.
    num_filas = int( np.ceil(fig_tot/fig_tot_fila) )
    plt.figure( figsize=( fig_tot_fila*fig_tamanio+2, num_filas*fig_tamanio+2 ) )
    target_neg, target_pos = targets
    for i, feat in enumerate(x.columns):
        plt.subplot(num_filas, int(fig_tot_fila), i+1);
        plt.title('%s' % feat)
        idx_pos = y == target_pos
        idx_neg= y == target_neg
        represento_doble_hist(x[feat][idx_pos].values, x[feat][idx_neg].values, nbins, 
                   density = density, title=('%s' % feat))

# %% [markdown]
# # Lectura de datos:

# %%
XY = pd.read_excel('data/default_of_credit_card_clients.xls', skiprows=[0])

# %%
print(u'- El número de filas en el dataset es: {}'.format(XY.shape[0]))
print(u'- El número de columnas en el dataset es: {}'.format(XY.shape[1]))
print(u'- Los nombres de las variables son: {}'.format(list(XY.columns)))
XY[:2]
# Out:
# - El número de filas en el dataset es: 30000
# - El número de columnas en el dataset es: 25
# - Los nombres de las variables son: ['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default payment next month']
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2       3913       3102        689          0          0
# 1      0      2       2682       1725       2682       3272       3455
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0          0         0       689         0         0         0         0
# 1       3261         0      1000      1000      1000         0      2000
#
#    default payment next month
# 0                           1
# 1                           1

# %% [markdown]
# ## Missings:

# %%
XY.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# ## Division en features X + target Y

# %%
X = XY.drop('default payment next month', axis=1)
Y = XY['default payment next month']

# %% [markdown]
# # Visualizaciones y correlaciones

# %% [markdown]
# ## Descriptivos básicos:

# %%
XY.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#               PAY_5         PAY_6      BILL_AMT1      BILL_AMT2     BILL_AMT3  \
# count  30000.000000  30000.000000   30000.000000   30000.000000  3.000000e+04
# mean      -0.266200     -0.291100   51223.330900   49179.075167  4.701315e+04
# std        1.133187      1.149988   73635.860576   71173.768783  6.934939e+04
# min       -2.000000     -2.000000 -165580.000000  -69777.000000 -1.572640e+05
# 25%       -1.000000     -1.000000    3558.750000    2984.750000  2.666250e+03
# 50%        0.000000      0.000000   22381.500000   21200.000000  2.008850e+04
# 75%        0.000000      0.000000   67091.000000   64006.250000  6.016475e+04
# max        8.000000      8.000000  964511.000000  983931.000000  1.664089e+06
#
#            BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count   30000.000000   30000.000000   30000.000000   30000.000000
# mean    43262.948967   40311.400967   38871.760400    5663.580500
# std     64332.856134   60797.155770   59554.107537   16563.280354
# min   -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%      2326.750000    1763.000000    1256.000000    1000.000000
# 50%     19052.000000   18104.500000   17071.000000    2100.000000
# 75%     54506.000000   50190.500000   49198.250000    5006.000000
# max    891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000

# %% [markdown]
# ## Boxplots:

# %%
X_normalizado = (X-X.mean())/X.std()

# %%
plt.figure(figsize=(15,7))
ax = sns.boxplot(data=X_normalizado)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.title(u'Representación de cajas de las variables independientes X')
plt.ylabel('Valor de la variable normalizada')
_ = plt.xlabel('Nombre de la variable')

# %% [markdown]
# ## Histogramas:

# %%
plt.figure(figsize=(18,20))
n = 0
for i, column in enumerate(X.columns):
    n+=1
    plt.subplot(5, 5, n)
    sns.distplot(X[column], bins=30)
    plt.title('Distribución var {}'.format(column))
plt.show()

# %% [markdown]
# ## Relación variable vs target:

# %%
relaciones_vs_target(X, Y)

# %%
hist_pos_neg_feat(X,Y)

# %% [markdown]
# ## Matriz de correlaciones:

# %%
matriz_correlaciones = XY.corr(method='pearson')
n_ticks = len(XY.columns)
plt.figure( figsize=(9, 9) )
plt.xticks(range(n_ticks), XY.columns, rotation='vertical')
plt.yticks(range(n_ticks), XY.columns)
plt.colorbar(plt.imshow(matriz_correlaciones, interpolation='nearest', 
                            vmin=-1., vmax=1., 
                            cmap=plt.get_cmap('Blues')))
_ = plt.title('Matriz de correlaciones de Pearson')

# %% [markdown]
# ## Variables con mayor correlación con la target:

# %%
correlaciones_target = matriz_correlaciones.values[ -1, : -1]
indices_inversos =  abs(correlaciones_target[ : ]).argsort()[ : : -1]
diccionario = {}
for nombre, correlacion in zip( X.columns[indices_inversos], list(correlaciones_target[indices_inversos] ) ):
    diccionario[nombre] = correlacion
pd.DataFrame.from_dict(diccionario, orient='index', columns=['Correlación con la target'])
# Out:
#            Correlación con la target
# PAY_0                       0.324794
# PAY_2                       0.263551
# PAY_3                       0.235253
# PAY_4                       0.216614
# PAY_5                       0.204149
# PAY_6                       0.186866
# LIMIT_BAL                  -0.153520
# PAY_AMT1                   -0.072929
# PAY_AMT2                   -0.058579
# PAY_AMT4                   -0.056827
# PAY_AMT3                   -0.056250
# PAY_AMT5                   -0.055124
# PAY_AMT6                   -0.053183
# SEX                        -0.039961
# EDUCATION                   0.028006
# MARRIAGE                   -0.024339
# BILL_AMT1                  -0.019644
# BILL_AMT2                  -0.014193
# BILL_AMT3                  -0.014076
# ID                         -0.013952
# AGE                         0.013890
# BILL_AMT4                  -0.010156
# BILL_AMT5                  -0.006760
# BILL_AMT6                  -0.005372

# %% [markdown]
# ## Estandarización previa de los datos:

# %%
obj_escalar = StandardScaler()
X_estandarizado = obj_escalar.fit_transform(X)

# %% [markdown]
# ## División en train y test:

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_estandarizado, Y, test_size=0.2, random_state=0)

# %% [markdown]
# # Aplicación de un modelo de redes neuronales

# %%
modelo = MLPClassifier()
parametros = {'solver': ['lbfgs'], 
              'max_iter': [100,200,300,500], # Iteraciones máximas en cada red
              'alpha': 10.0 ** -np.arange(1, 3), # Parámetro de regularización L2 para evitar sobreajuste
              'hidden_layer_sizes':np.arange(30, 35), # Número de neuronas en cada capa
              'random_state':[0]}

# %%
modelo_gs = GridSearchCV(modelo, param_grid=parametros, cv = 3, 
                         scoring='roc_auc', n_jobs=-1, verbose=10)
modelo_gs.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV 1/3; 1/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 1/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs;, score=0.767 total time=   1.2s
# [CV 1/3; 2/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 2/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs;, score=0.762 total time=   2.4s
# [CV 3/3; 2/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 2/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs;, score=0.765 total time=   2.2s
# [CV 2/3; 3/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 3/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs;, score=0.749 total time=   3.6s
# [CV 1/3; 4/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 4/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs;, score=0.756 total time=   5.7s
# [CV 3/3; 4/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 4/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs;, score=0.757 total time=   5.6s
# [CV 1/3; 6/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 6/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs;, score=0.753 total time=   2.4s
# [CV 3/3; 6/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 6/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs;, score=0.759 total time=   2.6s
# [CV 2/3; 7/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 7/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs;, score=0.748 total time=   3.5s
# [CV 1/3; 8/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 8/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs;, score=0.744 total time=   6.1s
# [CV 3/3; 8/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 8/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs;, score=0.749 total time=   6.0s
# [CV 2/3; 10/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 10/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs;, score=0.745 total time=   2.3s
# [CV 1/3; 11/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 11/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs;, score=0.758 total time=   3.8s
# [CV 3/3; 11/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 11/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs;, score=0.754 total time=   3.5s
# [CV 2/3; 12/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 12/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs;, score=0.741 total time=   6.9s
# [CV 1/3; 13/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 13/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs;, score=0.763 total time=   1.2s
# [CV 2/3; 13/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 13/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs;, score=0.752 total time=   1.3s
# [CV 3/3; 13/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 13/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs;, score=0.766 total time=   1.3s
# [CV 2/3; 14/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 14/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs;, score=0.749 total time=   2.5s
# [CV 1/3; 15/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 15/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs;, score=0.750 total time=   3.9s
# [CV 3/3; 15/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 15/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs;, score=0.755 total time=   3.6s
# [CV 2/3; 16/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 16/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs;, score=0.746 total time=   6.3s
# [CV 1/3; 17/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 17/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs;, score=0.760 total time=   1.3s
# [CV 2/3; 17/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 17/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs;, score=0.750 total time=   1.3s
# [CV 3/3; 17/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 17/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs;, score=0.766 total time=   1.2s
# [CV 2/3; 18/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 18/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs;, score=0.740 total time=   2.5s
# [CV 1/3; 19/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 19/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs;, score=0.752 total time=   3.7s
# [CV 3/3; 19/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 19/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs;, score=0.757 total time=   3.7s
# [CV 2/3; 20/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 20/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs;, score=0.734 total time=   6.2s
# [CV 1/3; 21/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 21/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs;, score=0.768 total time=   1.2s
# [CV 2/3; 21/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 21/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs;, score=0.756 total time=   1.1s
# [CV 3/3; 21/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 21/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs;, score=0.768 total time=   1.1s
# [CV 1/3; 22/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 22/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs;, score=0.764 total time=   2.2s
# [CV 3/3; 22/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 22/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs;, score=0.761 total time=   2.2s
# [CV 2/3; 23/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 23/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs;, score=0.744 total time=   3.4s
# [CV 1/3; 24/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [CV 2/3; 1/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 1/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs;, score=0.762 total time=   1.1s
# [CV 3/3; 1/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 1/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=100, random_state=0, solver=lbfgs;, score=0.772 total time=   1.1s
# [CV 2/3; 2/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 2/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs;, score=0.753 total time=   2.3s
# [CV 1/3; 3/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 3/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs;, score=0.757 total time=   3.5s
# [CV 3/3; 3/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 3/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs;, score=0.761 total time=   3.4s
# [CV 2/3; 4/40] START alpha=0.1, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 4/40] END alpha=0.1, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs;, score=0.747 total time=   5.7s
# [CV 1/3; 5/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 5/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs;, score=0.763 total time=   1.2s
# [CV 2/3; 5/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 5/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs;, score=0.754 total time=   1.2s
# [CV 3/3; 5/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 5/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs;, score=0.769 total time=   1.2s
# [CV 2/3; 6/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 6/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs;, score=0.751 total time=   2.4s
# [CV 1/3; 7/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 7/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs;, score=0.748 total time=   3.6s
# [CV 3/3; 7/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 7/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs;, score=0.754 total time=   3.6s
# [CV 2/3; 8/40] START alpha=0.1, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 8/40] END alpha=0.1, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs;, score=0.745 total time=   6.2s
# [CV 1/3; 9/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 9/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs;, score=0.766 total time=   1.2s
# [CV 2/3; 9/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 9/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs;, score=0.754 total time=   1.2s
# [CV 3/3; 9/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 9/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs;, score=0.763 total time=   1.2s
# [CV 1/3; 10/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 10/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs;, score=0.762 total time=   2.3s
# [CV 3/3; 10/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 10/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs;, score=0.756 total time=   2.4s
# [CV 2/3; 11/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 11/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs;, score=0.743 total time=   3.6s
# [CV 1/3; 12/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 12/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs;, score=0.754 total time=   5.6s
# [CV 3/3; 12/40] START alpha=0.1, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 12/40] END alpha=0.1, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs;, score=0.751 total time=   7.0s
# [CV 1/3; 14/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 14/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs;, score=0.756 total time=   2.4s
# [CV 3/3; 14/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 14/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs;, score=0.761 total time=   2.5s
# [CV 2/3; 15/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 15/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs;, score=0.749 total time=   3.6s
# [CV 1/3; 16/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 16/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs;, score=0.745 total time=   5.9s
# [CV 3/3; 16/40] START alpha=0.1, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 16/40] END alpha=0.1, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs;, score=0.753 total time=   5.9s
# [CV 1/3; 18/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 18/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs;, score=0.754 total time=   2.4s
# [CV 3/3; 18/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 18/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs;, score=0.760 total time=   2.5s
# [CV 2/3; 19/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 19/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs;, score=0.736 total time=   3.6s
# [CV 1/3; 20/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 20/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs;, score=0.747 total time=   6.1s
# [CV 3/3; 20/40] START alpha=0.1, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 20/40] END alpha=0.1, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs;, score=0.754 total time=   6.2s
# [CV 2/3; 22/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 22/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=200, random_state=0, solver=lbfgs;, score=0.748 total time=   2.2s
# [CV 1/3; 23/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 23/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs;, score=0.761 total time=   3.4s
# [CV 3/3; 23/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 23/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=300, random_state=0, solver=lbfgs;, score=0.757 total time=   3.3s
# [CV 2/3; 24/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 24/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs;, score=0.743 total time=   5.3s
# [CV 1/3; 25/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# GridSearchCV(cv=3, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'alpha': array([0.1 , 0.01]),
#                          'hidden_layer_sizes': array([30, 31, 32, 33, 34]),
#                          'max_iter': [100, 200, 300, 500], 'random_state': [0],
#                          'solver': ['lbfgs']},
#              scoring='roc_auc', verbose=10)

# %%
print(modelo_gs.best_params_, "\nROC AUC: {}".format(round(modelo_gs.best_score_,2)))
# Out:
# {'alpha': np.float64(0.1), 'hidden_layer_sizes': np.int64(30), 'max_iter': 100, 'random_state': 0, 'solver': 'lbfgs'}
# ROC AUC: 0.77

# %% [markdown]
# ## Mejores parámetros:

# %% [markdown]
# Igual que en el resto de modelos, obtenemos los mejores parámetros encontrados y ajustamos un modelo con esos parámetros:

# %%
mejor_modelo = MLPClassifier(**modelo_gs.best_params_, verbose=10)

# %%
mejor_modelo.fit(X_train, Y_train)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          781     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.03676D-01    |proj g|=  2.78722D-01
#
# At iterate    1    f=  6.00155D-01    |proj g|=  1.08937D-01
#
# At iterate    2    f=  5.25519D-01    |proj g|=  5.24316D-02
#
# At iterate    3    f=  5.03082D-01    |proj g|=  4.93361D-02
#
# At iterate    4    f=  4.93738D-01    |proj g|=  3.88902D-02
#
# At iterate    5    f=  4.67016D-01    |proj g|=  1.36122D-02
#
# At iterate    6    f=  4.61529D-01    |proj g|=  1.72088D-02
#
# At iterate    7    f=  4.57248D-01    |proj g|=  9.64157D-03
#
# At iterate    8    f=  4.54290D-01    |proj g|=  6.42644D-03
#
# At iterate    9    f=  4.51431D-01    |proj g|=  7.66683D-03
#
# At iterate   10    f=  4.47065D-01    |proj g|=  8.40426D-03
#
# At iterate   11    f=  4.45461D-01    |proj g|=  1.08649D-02
#  This problem is unconstrained.
# At iterate   12    f=  4.43934D-01    |proj g|=  3.40413D-03
#
# At iterate   13    f=  4.43123D-01    |proj g|=  3.30971D-03
#
# At iterate   14    f=  4.42357D-01    |proj g|=  4.36229D-03
#
# At iterate   15    f=  4.41252D-01    |proj g|=  2.05536D-02
#
# At iterate   16    f=  4.39806D-01    |proj g|=  5.02571D-03
#
# At iterate   17    f=  4.39351D-01    |proj g|=  2.64929D-03
#
# At iterate   18    f=  4.38542D-01    |proj g|=  3.17340D-03
#
# At iterate   19    f=  4.37765D-01    |proj g|=  6.58370D-03
#
# At iterate   20    f=  4.37417D-01    |proj g|=  9.88630D-03
#
# At iterate   21    f=  4.36354D-01    |proj g|=  3.17803D-03
#
# At iterate   22    f=  4.35963D-01    |proj g|=  2.60193D-03
#
# At iterate   23    f=  4.35265D-01    |proj g|=  2.69028D-03
#
# At iterate   24    f=  4.34289D-01    |proj g|=  2.88791D-03
#
# At iterate   25    f=  4.33603D-01    |proj g|=  4.81514D-03
#
# At iterate   26    f=  4.33045D-01    |proj g|=  3.23261D-03
#
# At iterate   27    f=  4.32601D-01    |proj g|=  4.51582D-03
#
# At iterate   28    f=  4.32360D-01    |proj g|=  7.93852D-03
#
# At iterate   29    f=  4.32051D-01    |proj g|=  2.87086D-03
#
# At iterate   30    f=  4.31617D-01    |proj g|=  2.75231D-03
#
# At iterate   31    f=  4.31214D-01    |proj g|=  4.21358D-03
#
# At iterate   32    f=  4.30886D-01    |proj g|=  6.91453D-03
#
# At iterate   33    f=  4.30556D-01    |proj g|=  1.82133D-03
#
# At iterate   34    f=  4.30332D-01    |proj g|=  1.74836D-03
#
# At iterate   35    f=  4.29886D-01    |proj g|=  1.70240D-03
#
# At iterate   36    f=  4.29353D-01    |proj g|=  2.57889D-03
#
# At iterate   37    f=  4.28846D-01    |proj g|=  6.72043D-03
#
# At iterate   38    f=  4.28557D-01    |proj g|=  8.08299D-03
#
# At iterate   39    f=  4.27753D-01    |proj g|=  2.22177D-03
#
# At iterate   40    f=  4.27469D-01    |proj g|=  1.88730D-03
#
# At iterate   41    f=  4.27190D-01    |proj g|=  2.84961D-03
#
# At iterate   42    f=  4.27090D-01    |proj g|=  1.38867D-02
#
# At iterate   43    f=  4.26792D-01    |proj g|=  2.88352D-03
#
# At iterate   44    f=  4.26653D-01    |proj g|=  1.66931D-03
#
# At iterate   45    f=  4.26455D-01    |proj g|=  3.55231D-03
#
# At iterate   46    f=  4.26064D-01    |proj g|=  7.70969D-03
#
# At iterate   47    f=  4.25714D-01    |proj g|=  4.54232D-03
#
# At iterate   48    f=  4.25435D-01    |proj g|=  3.13021D-03
#
# At iterate   49    f=  4.25161D-01    |proj g|=  1.60499D-03
#
# At iterate   50    f=  4.24811D-01    |proj g|=  2.37182D-03
#
# At iterate   51    f=  4.24662D-01    |proj g|=  7.82355D-03
#
# At iterate   52    f=  4.24141D-01    |proj g|=  2.43010D-03
#
# At iterate   53    f=  4.23746D-01    |proj g|=  1.88857D-03
#
# At iterate   54    f=  4.23499D-01    |proj g|=  1.96135D-03
#
# At iterate   55    f=  4.23339D-01    |proj g|=  1.10392D-02
#
# At iterate   56    f=  4.23048D-01    |proj g|=  6.45204D-03
#
# At iterate   57    f=  4.22830D-01    |proj g|=  2.26781D-03
#
# At iterate   58    f=  4.22714D-01    |proj g|=  6.04854D-03
#
# At iterate   59    f=  4.22537D-01    |proj g|=  3.40133D-03
#
# At iterate   60    f=  4.22232D-01    |proj g|=  3.87850D-03
#
# At iterate   61    f=  4.21828D-01    |proj g|=  2.32342D-03
#
# At iterate   62    f=  4.21478D-01    |proj g|=  5.00615D-03
#
# At iterate   63    f=  4.21186D-01    |proj g|=  3.67603D-03
#
# At iterate   64    f=  4.21026D-01    |proj g|=  1.96776D-03
#
# At iterate   65    f=  4.20899D-01    |proj g|=  4.05959D-03
#
# At iterate   66    f=  4.20731D-01    |proj g|=  1.79288D-03
#
# At iterate   67    f=  4.20591D-01    |proj g|=  2.64667D-03
#
# At iterate   68    f=  4.20444D-01    |proj g|=  1.07576D-02
#
# At iterate   69    f=  4.20238D-01    |proj g|=  2.48355D-03
#
# At iterate   70    f=  4.20129D-01    |proj g|=  2.42383D-03
#
# At iterate   71    f=  4.19985D-01    |proj g|=  4.60292D-03
#
# At iterate   72    f=  4.19845D-01    |proj g|=  4.07804D-03
#
# At iterate   73    f=  4.19746D-01    |proj g|=  2.37146D-03
#
# At iterate   74    f=  4.19609D-01    |proj g|=  1.86942D-03
#
# At iterate   75    f=  4.19491D-01    |proj g|=  2.26083D-03
#
# At iterate   76    f=  4.19186D-01    |proj g|=  2.07056D-03
#
# At iterate   77    f=  4.18928D-01    |proj g|=  2.90774D-03
#
# At iterate   78    f=  4.18766D-01    |proj g|=  3.35409D-03
#
# At iterate   79    f=  4.18627D-01    |proj g|=  2.39437D-03
#
# At iterate   80    f=  4.18534D-01    |proj g|=  3.37872D-03
#
# At iterate   81    f=  4.18374D-01    |proj g|=  7.98453D-03
#
# At iterate   82    f=  4.18225D-01    |proj g|=  7.09853D-03
#
# At iterate   83    f=  4.18102D-01    |proj g|=  2.91509D-03
#
# At iterate   84    f=  4.17988D-01    |proj g|=  2.07852D-03
#
# At iterate   85    f=  4.17880D-01    |proj g|=  3.23927D-03
#
# At iterate   86    f=  4.17818D-01    |proj g|=  8.37435D-03
#
# At iterate   87    f=  4.17661D-01    |proj g|=  2.74295D-03
#
# At iterate   88    f=  4.17599D-01    |proj g|=  2.10692D-03
#
# At iterate   89    f=  4.17460D-01    |proj g|=  4.39740D-03
#
# At iterate   90    f=  4.17315D-01    |proj g|=  3.44360D-03
#
# At iterate   91    f=  4.17123D-01    |proj g|=  4.25056D-03
#
# At iterate   92    f=  4.16933D-01    |proj g|=  1.61191D-03
#
# At iterate   93    f=  4.16811D-01    |proj g|=  2.48951D-03
#
# At iterate   94    f=  4.16600D-01    |proj g|=  2.13270D-03
#
# At iterate   95    f=  4.16514D-01    |proj g|=  1.48888D-02
#
# At iterate   96    f=  4.16285D-01    |proj g|=  2.42201D-03
#
# At iterate   97    f=  4.16180D-01    |proj g|=  2.32143D-03
#
# At iterate   98    f=  4.16111D-01    |proj g|=  2.41871D-03
#
# At iterate   99    f=  4.15972D-01    |proj g|=  2.52583D-03
#
# At iterate  100    f=  4.15917D-01    |proj g|=  3.25816D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   781    100    105      1     0     0   3.258D-03   4.159D-01
#   F =  0.41591747042141775
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# MLPClassifier(alpha=np.float64(0.1), hidden_layer_sizes=np.int64(30),
#               max_iter=100, random_state=0, solver='lbfgs', verbose=10)

# %% [markdown]
# ## Análisis de las predicciones:

# %%
y_test_pred_prob = mejor_modelo.predict_proba(X_test) 
y_test_pred_prob_pos = y_test_pred_prob[np.where(Y_test == 1)[0]]
y_test_pred_prob_neg = y_test_pred_prob[np.where(Y_test == 0)[0]]

# %%
preds = y_test_pred_prob[:,1]
fpr, tpr, threshold = metrics.roc_curve(Y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.figure(figsize=(10,7))
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
represento_doble_hist(y_test_pred_prob_pos[:, 1], y_test_pred_prob_neg[:, 1], n_bins=21, density=0)

# %% [markdown]
# ## Umbralizo las predicciones:

# %%
umbral = 0.5
y_umbralizadas = 1*(y_test_pred_prob[:, 1] > umbral)

# %%
print(u"Matriz de confusión\n", metrics.confusion_matrix(Y_test, y_umbralizadas))
print("\nAccuracy\t{}".format(round(metrics.accuracy_score(Y_test, y_umbralizadas),2)))  
print("Sensitividad\t{}".format(round(metrics.recall_score(Y_test, y_umbralizadas),2)))
print(u"Precisión\t{}".format(round(metrics.precision_score(Y_test, y_umbralizadas),2)))
# Out:
# Matriz de confusión
#  [[4448  255]
#  [ 800  497]]
#
# Accuracy	0.82
# Sensitividad	0.38
# Precisión	0.66
# [CV 1/3; 24/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs;, score=0.756 total time=   5.5s
# [CV 3/3; 24/40] START alpha=0.01, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 24/40] END alpha=0.01, hidden_layer_sizes=30, max_iter=500, random_state=0, solver=lbfgs;, score=0.754 total time=   5.6s
# [CV 1/3; 26/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 26/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs;, score=0.755 total time=   2.4s
# [CV 3/3; 26/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 26/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs;, score=0.756 total time=   2.4s
# [CV 2/3; 27/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 27/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs;, score=0.743 total time=   3.8s
# [CV 1/3; 28/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 28/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs;, score=0.749 total time=   5.9s
# [CV 3/3; 28/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 28/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs;, score=0.749 total time=   7.3s
# [CV 2/3; 30/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 30/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs;, score=0.751 total time=   3.5s
# [CV 1/3; 31/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 31/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs;, score=0.752 total time=   5.2s
# [CV 3/3; 31/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 31/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs;, score=0.756 total time=   4.2s
# [CV 2/3; 32/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 32/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs;, score=0.745 total time=   9.6s
# [CV 1/3; 33/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 33/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs;, score=0.765 total time=   1.6s
# [CV 2/3; 33/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 33/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs;, score=0.753 total time=   1.2s
# [CV 3/3; 33/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 33/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=100, random_state=0, solver=lbfgs;, score=0.765 total time=   1.4s
# [CV 1/3; 34/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 34/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs;, score=0.759 total time=   2.5s
# [CV 3/3; 34/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 34/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs;, score=0.760 total time=   2.5s
# [CV 2/3; 35/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 35/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs;, score=0.748 total time=   3.6s
# [CV 1/3; 36/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 36/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs;, score=0.752 total time=   6.0s
# [CV 3/3; 36/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 36/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs;, score=0.749 total time=   6.1s
# [CV 2/3; 38/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 38/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs;, score=0.738 total time=   2.7s
# [CV 1/3; 39/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 39/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs;, score=0.747 total time=   3.8s
# [CV 3/3; 39/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 39/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs;, score=0.751 total time=   3.7s
# [CV 2/3; 40/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 40/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs;, score=0.733 total time=   6.2s
# [CV 1/3; 25/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs;, score=0.763 total time=   1.3s
# [CV 2/3; 25/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 25/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs;, score=0.753 total time=   1.2s
# [CV 3/3; 25/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 25/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=100, random_state=0, solver=lbfgs;, score=0.768 total time=   1.3s
# [CV 2/3; 26/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 26/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=200, random_state=0, solver=lbfgs;, score=0.745 total time=   2.4s
# [CV 1/3; 27/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 27/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs;, score=0.751 total time=   3.5s
# [CV 3/3; 27/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 27/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=300, random_state=0, solver=lbfgs;, score=0.752 total time=   3.7s
# [CV 2/3; 28/40] START alpha=0.01, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 28/40] END alpha=0.01, hidden_layer_sizes=31, max_iter=500, random_state=0, solver=lbfgs;, score=0.742 total time=   6.4s
# [CV 1/3; 29/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 29/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs;, score=0.767 total time=   1.7s
# [CV 2/3; 29/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 29/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs;, score=0.756 total time=   1.5s
# [CV 3/3; 29/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 29/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=100, random_state=0, solver=lbfgs;, score=0.768 total time=   1.1s
# [CV 1/3; 30/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 30/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs;, score=0.758 total time=   3.0s
# [CV 3/3; 30/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 30/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=200, random_state=0, solver=lbfgs;, score=0.760 total time=   3.7s
# [CV 2/3; 31/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 31/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=300, random_state=0, solver=lbfgs;, score=0.746 total time=   4.9s
# [CV 1/3; 32/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 32/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs;, score=0.742 total time=   9.0s
# [CV 3/3; 32/40] START alpha=0.01, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 32/40] END alpha=0.01, hidden_layer_sizes=32, max_iter=500, random_state=0, solver=lbfgs;, score=0.753 total time=   7.4s
# [CV 2/3; 34/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs
# [CV 2/3; 34/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=200, random_state=0, solver=lbfgs;, score=0.750 total time=   2.5s
# [CV 1/3; 35/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs
# [CV 1/3; 35/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs;, score=0.755 total time=   3.6s
# [CV 3/3; 35/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs
# [CV 3/3; 35/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=300, random_state=0, solver=lbfgs;, score=0.754 total time=   3.7s
# [CV 2/3; 36/40] START alpha=0.01, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs
# [CV 2/3; 36/40] END alpha=0.01, hidden_layer_sizes=33, max_iter=500, random_state=0, solver=lbfgs;, score=0.746 total time=   5.9s
# [CV 1/3; 37/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs
# [CV 1/3; 37/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs;, score=0.756 total time=   1.2s
# [CV 2/3; 37/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs
# [CV 2/3; 37/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs;, score=0.744 total time=   1.2s
# [CV 3/3; 37/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs
# [CV 3/3; 37/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=100, random_state=0, solver=lbfgs;, score=0.767 total time=   1.2s
# [CV 1/3; 38/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs
# [CV 1/3; 38/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs;, score=0.749 total time=   2.6s
# [CV 3/3; 38/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs
# [CV 3/3; 38/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=200, random_state=0, solver=lbfgs;, score=0.754 total time=   2.5s
# [CV 2/3; 39/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs
# [CV 2/3; 39/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=300, random_state=0, solver=lbfgs;, score=0.736 total time=   3.8s
# [CV 1/3; 40/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs
# [CV 1/3; 40/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs;, score=0.744 total time=   6.2s
# [CV 3/3; 40/40] START alpha=0.01, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs
# [CV 3/3; 40/40] END alpha=0.01, hidden_layer_sizes=34, max_iter=500, random_state=0, solver=lbfgs;, score=0.750 total time=   4.9s
